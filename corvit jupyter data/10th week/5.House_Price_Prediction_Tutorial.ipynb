# %% [markdown]
# # 🏡 House Price Prediction - AI Model from Scratch
#
# ![SNOWFALL](Capture.PNG)
#
#
# ![SNOWFALL](Capture2.PNG)

# %% [markdown]
# ### 🧰 Step 1: Setup and Import Libraries

# %%
import pandas as pd # for data preprocessing
import numpy as np # for data preprocessing
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

# sklearn >> used for AI models training, testing, data scaling etc.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### 📦 Step 2: Load the Dataset

# %%
# url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
url = "BostonHousing.csv"
df = pd.read_csv(url)

# %%
df.head(8)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172  96.1  5.9505    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1

# %%
df.iloc[200:215] # index location
# Out:
#         crim    zn  indus  chas     nox     rm    age     dis  rad  tax  \
# 200  0.01778  95.0   1.47     0  0.4030  7.135   13.9  7.6534    3  402
# 201  0.03445  82.5   2.03     0  0.4150  6.162   38.4  6.2700    2  348
# 202  0.02177  82.5   2.03     0  0.4150  7.610   15.7  6.2700    2  348
# 203  0.03510  95.0   2.68     0  0.4161  7.853   33.2  5.1180    4  224
# 204  0.02009  95.0   2.68     0  0.4161  8.034   31.9  5.1180    4  224
# 205  0.13642   0.0  10.59     0  0.4890  5.891   22.3  3.9454    4  277
# 206  0.22969   0.0  10.59     0  0.4890  6.326   52.5  4.3549    4  277
# 207  0.25199   0.0  10.59     0  0.4890  5.783   72.7  4.3549    4  277
# 208  0.13587   0.0  10.59     1  0.4890  6.064   59.1  4.2392    4  277
# 209  0.43571   0.0  10.59     1  0.4890  5.344  100.0  3.8750    4  277
# 210  0.17446   0.0  10.59     1  0.4890  5.960   92.1  3.8771    4  277
# 211  0.37578   0.0  10.59     1  0.4890  5.404   88.6  3.6650    4  277
# ...

# %%
df.tail(4)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %% [markdown]
# ### 🔍 Step 3: Exploratory Data Analysis (EDA)

# %%
print(f"Rows and Columns: {df.shape}")
df.info() # null values, values types
# Out:
# Rows and Columns: (506, 14)
# <class 'pandas.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe() # statistical features
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# df.isnull()
# df.sum()

df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ### 🛠️ Step 4: Data Preprocessing

# %%
# Separate features & label column
X = df.drop("medv", axis=1) # features >> removing Target variable 'medv'
y = df["medv"] #label >> select Target variable

scaler = StandardScaler() # initialize scaling model

'''
scaler.fit(X)
X_scaled = scaler.transform(X)

X_scaled = StandardScaler().fit(X).transform(X)
'''

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### 🔄 Step 5: Train-Test Split

# %%
# 20% data will be used as Testset and remaining 80% data will be used as Training set

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"Train size: {X_train.shape}")
print(f"Test size: {X_test.shape}")
# Out:
# Train size: (404, 13)
# Test size: (102, 13)

# %% [markdown]
# ## ✅ Step 6: Train a Linear Regression Model

# %%
model = LinearRegression() # model intialize
model.fit(X_train, y_train) #Training
# Out:
# LinearRegression()

# %% [markdown]
# ### 🔍 Step 7: Model Evaluation

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 24.29
# R^2 Score: 0.67

# %% [markdown]
# ### 📈 Step 8: Visualizing Predictions

# %%
plt.figure(figsize=(4, 4))
plt.scatter(y_test, y_pred, c='crimson')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue')
plt.grid()
plt.show()

# %% [markdown]
# ## 🧠 Step 9: Train 3 More Regresion Models and Compare the performance

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

'''
model = DecisionTreeRegressor() # model intialize
model.fit(X_train, y_train) #Training
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

model = RandomForestRegressor() # model intialize
model.fit(X_train, y_train) #Training
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
'''



models = {
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42),
    "K-Nearest Neighbors": KNeighborsRegressor(),
}

for name, model in models.items(): # 1st Iteration >>  "Decision Tree": DecisionTreeRegressor(random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{name} - MSE: {mse:.2f}, R^2: {r2:.2f}")
# Out:
# Decision Tree - MSE: 10.42, R^2: 0.86
# Random Forest - MSE: 7.93, R^2: 0.89
# K-Nearest Neighbors - MSE: 20.66, R^2: 0.72

# %% [markdown]
# ### 📊 Compare Models

# %%
results = []
for name, model in models.items():
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    results.append((name, r2))

model_names, r2_scores = zip(*results)
plt.figure(figsize=(8, 4))
sns.barplot(x=list(model_names), y=list(r2_scores))
plt.title("R^2 Score Comparison")
plt.ylabel("R^2 Score")
plt.show()

# %% [markdown]
# ## Test the AI model prediction on a sample data

# %%
# Let take a sample
X_test[101]
# Out:
# array([-0.409448  , -0.48772236,  0.24705682, -0.27259857, -1.01668877,
#         0.00194553, -0.83833697,  0.33635091, -0.52300145, -0.06080135,
#         0.1130321 ,  0.29116915, -0.52047412])

# %%
# let's check actual price for this sample
y_test[101]
# Out:
# np.float64(26.5)

# %%
sample_X = X_test[101].reshape(1, -1)

# Get predictions from the Linear Regression model (or any trained model)
sample_y_pred = lr.predict(sample_X)

print(f"Actual value: {y_test[101]:.2f}")
print(f"Linear Regression Model Prediction: {sample_y_pred[0]:.2f}")
# Out:
# Actual value: 26.50
# Linear Regression Model Prediction: 24.48
