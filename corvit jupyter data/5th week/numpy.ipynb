# %%
# !pip install numpy

# %%
import numpy as np

# %%
list1 = [1,2,3,4]
arr1 = np.array(list1)
print(f"arr1: {arr1}, datatype: {type(arr1)}")
# Out:
# arr1: [1 2 3 4], datatype: <class 'numpy.ndarray'>

# %%
ar_list = [1,2,3,4]
print(f"ar_list: {ar_list}, datatype: {type(ar_list)}")
# Out:
# ar_list: [1, 2, 3, 4], datatype: <class 'list'>

# %%
vector = np.array([1,2,3])
print('vector :',vector)
# Out:
# vector : [1 2 3]

# %%
matrix=np.array([[1,2,3],[4,5,6]])
print('matrix',matrix)
# Out:
# matrix [[1 2 3]
#  [4 5 6]]

# %%
tensor=np.array([[[1,2,44],[3,4,55]],
         [[5,6,66],[7,8,77]]])
print('tensor',tensor)
# Out:
# tensor [[[ 1  2 44]
#   [ 3  4 55]]
#
#  [[ 5  6 66]
#   [ 7  8 77]]]

# %%
print(tensor.shape)
print(tensor.size)
# Out:
# (2, 2, 3)
# 12

# %%
tensor.ndim
# Out:
# 3
