# %%
print('hi')
# Out:
# hi

# %%
a=10
print(a)
d=5
# Out:
# 10

# %%
print(a)
# Out:
# 10

# %% [markdown]
# # vhj

# %% [markdown]
# *hjhk*

# %% [markdown]
# > blockquote

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# `code`

# %% [markdown]
# [title](https://www.example.com)

# %% [markdown]
# [fb](https://www.facebook.com)

# %% [markdown]
# 	| Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
#
# | Paragraph | Text |

# %%
	| Syntax | Description |
| ----------- | ----------- |
| ALi| python |
| Paragraph | Hello |

# %% [markdown]
# ![alt text]([WhatsApp Image 2026-02-13 at 6.54.41 PM](http://localhost:8888/edit/Documents/WhatsApp%20Image%202026-02-13%20at%206.54.41%20PM.jpeg))

# %% [markdown]
# ### My Great Heading {#custom-id}

# %% [markdown]
# ---
