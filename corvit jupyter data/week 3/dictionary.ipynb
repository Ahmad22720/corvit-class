# %%
country_capitals = {
  "United States": "Washington D.C.", 
  "Italy": "Rome" 
}
print()
# print dictionary keys one by one
for country in country_capitals:
    print(country)

print()

# print dictionary values one by one
for country in country_capitals:
    capital = country_capitals[country]
    print(capital)
# Out:
# United States
# Italy
# 2
# Washington D.C.
# Rome

# %%
print(len(country_capitals))
# Out:
# 2

# %%
# create a dictionary
marks = { 'Physics': 67, 'Chemistry': 72, 'Math': 89 ,'ahmad':78}

element = marks.pop('ahmad')

print('Popped Marks:', element)
print('other Marks:', marks)
# Out:
# Popped Marks: 78
# other Marks: {'Physics': 67, 'Chemistry': 72, 'Math': 89}

# %%
print(marks.values())
# Out:
# dict_values([67, 72, 89])

# %%
exam={'ahmad':28,
     'ali':39,
     'akl':38}
result=exam.get('ahmad')
print(result)
# Out:
# 28

# %%
person = {'name': 'Phill', 'age': 22}
print('Name: ', person.get('name'))

print('Age: ', person.get('age'))

# value is not provided
print('Salary: ', person.get('salary'))


# value is provided
print('Salary: ', person.get('salary', 0.0))
# Out:
# Name:  Phill
# Age:  22
# Salary:  None
# Salary:  0.0

# %%
student={'name':'Ali','age':18,}
print('Name :',student.get('name'))
print('Age :',student.get('age'))
# Out:
# Name : ali
# Age : 18

# %% [markdown]
# # value is not provided

# %%
print('Salary: ', person.get('salary'))
# Out:
# Salary:  None

# %% [markdown]
# # value is provided

# %%
print('Salary: ', person.get('salary', 0.0))
# Out:
# Salary:  0.0

# %%
print('Name :',student.get('name'))
print('Age :',student.get('age'))
print('Salary: ', person.get('salary', 0.0))
# Out:
# Name : ali
# Age : 18
# Salary:  0.0
