# %% [markdown]
# ### dict{"name : ali", "age:18","city : multan","institute : corvit",}

# %%
std={"name" :"ali", "age":18,"city" :" multan","institute" : "corvit"}
print(a)
# Out:
# {'name': 'ali', 'age': 18, 'city': ' multan', 'institute': 'corvit'}

# %% [markdown]
# ### add new value in dictionary

# %%
std["District:"]="lodhran"
print('updated file is:')
print(std)
# Out:
# updated file is:
# {'name': 'ali', 'age': 18, 'city': ' multan', 'institute': 'corvit', 'District:': 'lodhran'}

# %% [markdown]
# ### access value of city

# %%
print('city :',std.get('city'))
# Out:
# city :  multan

# %% [markdown]
# ## 2. task is  to remove values

# %%
# remove last value pair (institute)
s= std.pop('institute','corvit')
print('the removed value is :',s)
print('the remaining values are  :',std)
# Out:
# the removed value is : corvit
# the remaining values are  : {'name': 'ali', 'age': 18, 'city': ' multan', 'District:': 'lodhran'}

# %%
for i ,j in std.items():
    print("values are :",i,':',j)
# Out:
# values are : name : ali
# values are : age : 18
# values are : city :  multan
# values are : District: : lodhran

# %%
# check if key exist is 
if 'city' in std:
        print(' existed in the value name is :',std.get('city'))
else:
        print('value does not exits')
# Out:
#  existed in the value name is :  multan

# %% [markdown]
# ## task number 3 merge both dictionaries

# %%
numbers={'ten':10,'twenty':20, 'thirty':30}
num={'forty':40,'fifty':50,'sixty':60}
nm=numbers | num #with the help of chat gpt
numbers.update(num)# own method
print(nm)
print('merged value is',numbers)
# Out:
# {'ten': 10, 'twenty': 20, 'thirty': 30, 'forty': 40, 'fifty': 50, 'sixty': 60}
# merged value is {'ten': 10, 'twenty': 20, 'thirty': 30, 'forty': 40, 'fifty': 50, 'sixty': 60}

# %% [markdown]
# ## string function

# %%
string ='navttc'
stri=set(string)
print(stri)
# Out:
# {'a', 'n', 'v', 't', 'c'}

# %%
for char in string:
    print(char,':',string.count(char))
# Out:
# n : 1
# a : 1
# v : 1
# t : 2
# t : 2
# c : 1
