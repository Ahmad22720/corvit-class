# %% [markdown]
# ### using for loop

# %%
numbers = [1, 2, 3, 4, 5]
square_numbers = []
for num in numbers:
    square_numbers.append(num*num)

print (square_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### using list comprehension

# %%
numbers = [1, 2, 3, 4, 5]
# create a new list using list comprehension
square_numbers=[num*num for num in numbers]
print (square_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Conditionals in List Comprehension

# %%
even_numbers=[num for num in range(1,20) if num%2==0]
print('even numbers are :', even_numbers)
# Out:
# even numbers are : [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %%
word ='ahmad ali'
vowels='aeiou'
ls=[char for char in word if char in vowels]

print (ls)
# Out:
# ['a', 'a', 'a', 'i']

# %%
fruits = ["apple", "banana",'alu', "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'alu', 'mango']

# %%
newlist = [x for x in fruits if x != "apple"]
print(newlist)
# Out:
# ['banana', 'alu', 'cherry', 'kiwi', 'mango']
