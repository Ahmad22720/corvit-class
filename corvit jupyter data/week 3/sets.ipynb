# %%
num={1,101,2,390,2}
print('number of set ',num)
# Out:
# number of set  {1, 2, 101, 390}

# %% [markdown]
# # using add() method

# %%
num.add(32)
print(num)
min(num)
max(num)
all(num)
sum(num)
# Out:
# {32, 1, 2, 101, 390}
# 526

# %%
company={'google','amazon'}
tech_company={'invoone','i2c','adash'}
print('before useung update function',company,tech_company)
company.update(tech_company)
print('after using update function :',company)
# Out:
# before useung update function {'amazon', 'google'} {'invoone', 'adash', 'i2c'}
# after using update function : {'adash', 'invoone', 'amazon', 'google', 'i2c'}
